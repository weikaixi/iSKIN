# %%
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import chain
from numpy import genfromtxt
import csv
from matplotlib import pyplot as plt
from math import sqrt
from matplotlib import pyplot
import gzip
import seaborn as sns
import operator
from functools import reduce
import joblib
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelEncoder

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('XGboostbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
precision1,recall1,_ = precision_recall_curve(y_test,probas_[:,1])
auc(recall1,precision1)
# Out:
# 0.7609678670201339

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('RFbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
precision2,recall2,_ = precision_recall_curve(y_test,probas_[:,1])
auc(recall2,precision2)
# Out:
# 0.7430440670521743

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('LightGBMbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
precision3,recall3,_ = precision_recall_curve(y_test,probas_[:,1])
auc(recall3,precision3)
# Out:
# 0.7506796957952264

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('KNNbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
precision4,recall4,_ = precision_recall_curve(y_test,probas_[:,1])
auc(recall4,precision4)
# Out:
# 0.7327594845514771

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('SVMbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
precision5,recall5,_ = precision_recall_curve(y_test,probas_[:,1])
auc(recall5,precision5)
# Out:
# 0.7120668001723317

# %%
plt.plot(recall1,precision1,recall2,precision2,recall3,precision3,recall4,precision4,recall5,precision5,lw=1)
plt.title('Precision-Recall Curve') 
plt.legend(labels = ['XGBoost:AUC=0.760','RF:AUC=0.743','LightGBM:AUC=0.750','KNN:AUC=0.732','SVM:AUC=0.712'], loc = 'lower left') 
plt.ylabel('Precision',fontsize=14)
plt.xlabel('Recall',fontsize=14)
plt.xlim(xmax=1.1)
plt.ylim(ymax=1.1,ymin=0)
fig = plt.gcf()
plt.show()
fig.savefig('PR1.pdf', dpi=300)

# %% [markdown]
# # below is ROC

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('XGboostbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
predictions = probas_[:,1]
false_positive_rate1, true_positive_rate1,_ = roc_curve(y_test, predictions)
roc_auc = auc(false_positive_rate1, true_positive_rate1)
roc_auc
# Out:
# 0.8047964305633016

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('RFbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
predictions = probas_[:,1]
false_positive_rate2, true_positive_rate2,_ = roc_curve(y_test, predictions)
roc_auc = auc(false_positive_rate2, true_positive_rate2)
roc_auc
# Out:
# 0.8209450894894286

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('LightGBMbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
predictions = probas_[:,1]
false_positive_rate3, true_positive_rate3,_ = roc_curve(y_test, predictions)
roc_auc = auc(false_positive_rate3, true_positive_rate3)
roc_auc
# Out:
# 0.8015514881103281

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('KNNbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
predictions = probas_[:,1]
false_positive_rate4, true_positive_rate4,_ = roc_curve(y_test, predictions)
roc_auc = auc(false_positive_rate4, true_positive_rate4)
roc_auc
# Out:
# 0.7938193986716017

# %%
f = open('testset_withVAEfeature.csv')
df = pd.read_csv(f)
X_test = df.drop(["ID", "SMILES","label"], axis=1)
y_test = df["label"]
le = LabelEncoder()
y_test = le.fit_transform(y_test)
classifier= joblib.load('SVMbest_model.pkl')
probas_ = classifier.predict_proba(X_test)
predictions = probas_[:,1]
false_positive_rate5, true_positive_rate5,_ = roc_curve(y_test, predictions)
roc_auc = auc(false_positive_rate5, true_positive_rate5)
roc_auc
# Out:
# 0.7850225624904934

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate1, true_positive_rate1,false_positive_rate2, true_positive_rate2,false_positive_rate3, true_positive_rate3,false_positive_rate4, true_positive_rate4,false_positive_rate5,true_positive_rate5)
plt.legend(labels = ['XGBoost:AUC=0.804','RF:AUC=0.820','LightGBM:AUC=0.801','KNN:AUC=0.793','SVM:AUC=0.785'], loc = 'lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.1])
plt.ylim([-0.1,1.1])
plt.ylabel('True Positive Rate',fontsize=14)
plt.xlabel('False Positive Rate',fontsize=14)
fig = plt.gcf()
plt.show()
fig.savefig('ROC2.pdf', dpi=300)
